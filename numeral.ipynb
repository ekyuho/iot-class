# %% [markdown]
# <a href="https://colab.research.google.com/github/ekyuho/iot-class/blob/main/numeral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(256):
  print(i, hex(i), bin(i))
# Out:
# 0 0x0 0b0
# 1 0x1 0b1
# 2 0x2 0b10
# 3 0x3 0b11
# 4 0x4 0b100
# 5 0x5 0b101
# 6 0x6 0b110
# 7 0x7 0b111
# 8 0x8 0b1000
# 9 0x9 0b1001
# 10 0xa 0b1010
# 11 0xb 0b1011
# 12 0xc 0b1100
# 13 0xd 0b1101
# 14 0xe 0b1110
# 15 0xf 0b1111
# 16 0x10 0b10000
# 17 0x11 0b10001
# 18 0x12 0b10010
# 19 0x13 0b10011
# 20 0x14 0b10100
# 21 0x15 0b10101
# 22 0x16 0b10110
# 23 0x17 0b10111
# 24 0x18 0b11000
# 25 0x19 0b11001
# 26 0x1a 0b11010
# 27 0x1b 0b11011
# 28 0x1c 0b11100
# 29 0x1d 0b11101
# 30 0x1e 0b11110
# 31 0x1f 0b11111
# 32 0x20 0b100000
# 33 0x21 0b100001
# 34 0x22 0b100010
# 35 0x23 0b100011
# 36 0x24 0b100100
# 37 0x25 0b100101
# 38 0x26 0b100110
# 39 0x27 0b100111
# 40 0x28 0b101000
# 41 0x29 0b101001
# 42 0x2a 0b101010
# 43 0x2b 0b101011
# 44 0x2c 0b101100
# 45 0x2d 0b101101
# 46 0x2e 0b101110
# 47 0x2f 0b101111
# 48 0x30 0b110000
# 49 0x31 0b110001
# 50 0x32 0b110010
# 51 0x33 0b110011
# 52 0x34 0b110100
# 53 0x35 0b110101
# 54 0x36 0b110110
# 55 0x37 0b110111
# 56 0x38 0b111000
# ...

# %%
a=2**10
print(a, a/1000, 'K')
# Out:
# 1024 1.024 K

# %%
a=2**20
print(a, a/1000, 'K', a/1000000, 'M')
# Out:
# 1048576 1048.576 K 1.048576 M

# %%
a=2**30
print(a, a/1000, 'K', a/1000000, 'M', 1/1000000000, 'G')
# Out:
# 1073741824 1073741.824 K 1073.741824 M 1e-09 G

# %%
a=2**32
print(a/1000000000, 'G')
# Out:
# 4.294967296 G

# %%
d=[]
for i in range(256):
  d.append(65)
print(bytes(d))
# Out:
# b''

# %%
d=[]
for i in range(256):
  d.append(i)
print(bytes(d))
# Out:
# b'\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f !"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~'

# %%
with open('/content/drive/MyDrive/00IOT/text.dat') as f:
  d=f.read()
print(d)
# Out:
# 죽는 날까지 하늘을 우러러
# 한 점 부끄럼이 없기를,
# 잎새에 이는 바람에도
# 나는 괴로워했다.
# 별을 노래하는 마음으로
# 모든 죽어 가는 것을 사랑해야지
# 그리고 나한테 주어진 길을
# 걸어가야겠다.
# 오늘 밤에도 별이 바람에 스치운다.
# Look up to the sky until the day you die
# I hope you don't feel a shred of shame,
# Even as the wind rustles the leaves
# I was in pain.
# With a heart that sings of the stars
# You must love everything that passes away
# And the path that has been given to me
# I must walk.

# %%
print(len(bytes(d.encode('utf8'))), bytes(d.encode('utf8')))
# Out:
# %%
a1 = '가각'
print(len(bytes(a1.encode('euckr'))), bytes(a1.encode('euckr')))
# Out:
# 4 b'\xb0\xa1\xb0\xa2'

# %%
for b in bytes(d.encode('euckr')):
  print(b, hex(b), bin(b))
# Out:
# 193 0xc1 0b11000001
# 215 0xd7 0b11010111
# 180 0xb4 0b10110100
# 194 0xc2 0b11000010
# 32 0x20 0b100000
# 179 0xb3 0b10110011
# 175 0xaf 0b10101111
# 177 0xb1 0b10110001
# 238 0xee 0b11101110
# 193 0xc1 0b11000001
# 246 0xf6 0b11110110
# 32 0x20 0b100000
# 199 0xc7 0b11000111
# 207 0xcf 0b11001111
# 180 0xb4 0b10110100
# 195 0xc3 0b11000011
# 192 0xc0 0b11000000
# 187 0xbb 0b10111011
# 32 0x20 0b100000
# 191 0xbf 0b10111111
# 236 0xec 0b11101100
# 183 0xb7 0b10110111
# 175 0xaf 0b10101111
# 183 0xb7 0b10110111
# 175 0xaf 0b10101111
# 10 0xa 0b1010
# 199 0xc7 0b11000111
# 209 0xd1 0b11010001
# 32 0x20 0b100000
# 193 0xc1 0b11000001
# 161 0xa1 0b10100001
# 32 0x20 0b100000
# 186 0xba 0b10111010
# 206 0xce 0b11001110
# 178 0xb2 0b10110010
# 244 0xf4 0b11110100
# 183 0xb7 0b10110111
# 179 0xb3 0b10110011
# 192 0xc0 0b11000000
# 204 0xcc 0b11001100
# 32 0x20 0b100000
# 190 0xbe 0b10111110
# 248 0xf8 0b11111000
# 177 0xb1 0b10110001
# 226 0xe2 0b11100010
# 184 0xb8 0b10111000
# ...

# %%
print(bytes(d.encode('euckr')))
# Out:
# b"\xc1\xd7\xb4\xc2 \xb3\xaf\xb1\xee\xc1\xf6 \xc7\xcf\xb4\xc3\xc0\xbb \xbf\xec\xb7\xaf\xb7\xaf\n\xc7\xd1 \xc1\xa1 \xba\xce\xb2\xf4\xb7\xb3\xc0\xcc \xbe\xf8\xb1\xe2\xb8\xa6,\n\xc0\xd9\xbb\xf5\xbf\xa1 \xc0\xcc\xb4\xc2 \xb9\xd9\xb6\xf7\xbf\xa1\xb5\xb5\n\xb3\xaa\xb4\xc2 \xb1\xab\xb7\xce\xbf\xf6\xc7\xdf\xb4\xd9.\n\xba\xb0\xc0\xbb \xb3\xeb\xb7\xa1\xc7\xcf\xb4\xc2 \xb8\xb6\xc0\xbd\xc0\xb8\xb7\xce\n\xb8\xf0\xb5\xe7 \xc1\xd7\xbe\xee \xb0\xa1\xb4\xc2 \xb0\xcd\xc0\xbb \xbb\xe7\xb6\xfb\xc7\xd8\xbe\xdf\xc1\xf6\n\xb1\xd7\xb8\xae\xb0\xed \xb3\xaa\xc7\xd1\xc5\xd7 \xc1\xd6\xbe\xee\xc1\xf8 \xb1\xe6\xc0\xbb\n\xb0\xc9\xbe\xee\xb0\xa1\xbe\xdf\xb0\xda\xb4\xd9.\n\xbf\xc0\xb4\xc3 \xb9\xe3\xbf\xa1\xb5\xb5 \xba\xb0\xc0\xcc \xb9\xd9\xb6\xf7\xbf\xa1 \xbd\xba\xc4\xa1\xbf\xee\xb4\xd9.\nLook up to the sky until the day you die\nI hope you don't feel a shred of shame,\nEven as the wind rustles the leaves\nI was in pain.\nWith a heart that sings of the stars\nYou must love everything that passes away\nAnd the path th
# ...
